# %%
# Out:
# objc[12595]: Class CaptureDelegate is implemented in both /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/cv2/cv2.abi3.so (0x15e5e2840) and /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/mediapipe/.dylibs/libopencv_videoio.3.4.16.dylib (0x11fa2c860). One of the two will be used. Which one is undefined.
# objc[12595]: Class CVWindow is implemented in both /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/cv2/cv2.abi3.so (0x15e5e2890) and /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x11a944a68). One of the two will be used. Which one is undefined.
# objc[12595]: Class CVView is implemented in both /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/cv2/cv2.abi3.so (0x15e5e28b8) and /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x11a944a90). One of the two will be used. Which one is undefined.
# ...

# %%
def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %% [markdown]
# # 푸쉬업

# %%
if 푸쉬업 down: # (기준 y부터 몇 이상 내려갔을 때(0.2)  && 팔꿈치 각도 100 이하)
	if 팔꿈치 각도가 범위 안에 있는가? :
		score += 1
	if 겨드랑이 각도가 범위 안에 있는가? : 
		score += 1
	if 엉덩이 각도가 범위 안에 있는가? : 
		score += 1
	if 무릎 각도가 범위 안에 있는가? :
		score += 1
	if 목 각도가 범위 안에 있는가? :
		score += 1
	if 팔 너비
	---------------------------> 여기까지가 Down

if 푸쉬업 up: # 목 y좌표 아래에서 위로
	if 팔꿈치 각도가 범위 안에 있는가? :
		score += 1
	if 겨드랑이 각도가 범위 안에 있는가? : 
		score += 1
	if 엉덩이 각도가 범위 안에 있는가? : 
		score += 1
	if 무릎 각도가 범위 안에 있는가? :
		score += 1
	if 목 각도가 범위 안에 있는가? :
		score += 1
	if 팔너미

	---------------------------> 여기까지가 UP

if score == 10: 
	print('정확한 자세 입니다')
	올바른 count +1
	전체 카운트 + 1 
else:
	print('나쁜 자세입니다.')
	전체 카운트 + 1

	---------------------------> 최종 결과 산출

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 각도구하기
def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    
    return angle 


# 엉덩이 각도구하기
def rev_calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    angle = 360 - angle
    
    return angle 


# 거리구하기
def calculate_width(a,b):
    a = np.array(a) # First
    b = np.array(b) # End   
    
    width = ((a[0]-b[0])**2+(a[1]-b[1])**2)**0.5
    
    return width 



# './1.mp4'
cap = cv2.VideoCapture('./data/1.mp4')
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while True:
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            ##############################################################################################################

            #팔꿈치(어깨-팔꿈치-손목)
#             # 왼쪽 랜드마크
#             l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             l_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
#             l_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
#             # 오른쪽 랜드마크
#             r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
#             r_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
#             r_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            
#             # 왼쪽 각도
#             l_angle_elbow = calculate_angle(l_shoulder, l_elbow, l_wrist)
            
#             # 오른쪽 각도
#             r_angle_elbow = calculate_angle(r_shoulder, r_elbow, r_wrist)
            
#             # 각도를 눈에 보이게 표시
    
            
#             cv2.putText(image,  "LEFT :" + str(l_angle_elbow), 
#                             tuple(np.multiply(l_elbow, [500, 500]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
#             cv2.putText(image,  "RIGHT :" + str(r_angle_elbow), 
#                             tuple(np.multiply(r_elbow, [700, 700]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255, 255), 2, cv2.LINE_AA)
    
            
            ##############################################################################################################
        
            # 어깨(팔꿈치-어깨-엉덩이)
            #왼쪽 랜드마크
#             l_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
#             l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            
#             #오른쪽 랜드마크
#             r_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
#             r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
#             r_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            
#             # 왼쪽 각도
#             l_angle_shoulder = calculate_angle( l_elbow, l_shoulder, l_hip)
#             # 오른쪽 각도
#             r_angle_shoulder = calculate_angle( r_elbow, r_shoulder, r_hip)
            
#             # 각도를 눈에 보이게 표시
        
#             cv2.putText(image, "LEFT :" + str(l_angle_shoulder), 
#                            tuple(np.multiply(l_hip, [900, 900]).astype(int)), 
#                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
#             cv2.putText(image, "RIGHT :" + str(r_angle_shoulder), 
#                            tuple(np.multiply(r_hip, [450, 450]).astype(int)), 
#                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
        
            
            ##############################################################################################################
            
             #엉덩이(어깨-엉덩이-무릎)
            # 왼쪽 랜드마크
#             l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#             l_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#             # 오른쪽 랜드마크
#             r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
#             r_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
#             r_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            
#             # 왼쪽 각도
#             l_angle_hip = rev_calculate_angle(l_shoulder, l_hip, l_knee)
            
#             # 오른쪽 각도
#             r_angle_hip = rev_calculate_angle(r_shoulder, r_hip, r_knee)
            
            
            
#             #각도를 눈에 보이게 표시
            
#             cv2.putText(image, "LEFT_HIP:" + str(l_angle_hip), 
#                             tuple(np.multiply(l_hip, [100, 100]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
#             cv2.putText(image, "RIGHT_HIP :" +  str(r_angle_hip), 
#                             tuple(np.multiply(r_hip, [100, 200]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)

            
            ##############################################################################################################
            
            #무릎(엉덩이-무릎-발목)
            # 왼쪽 랜드마크
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#             l_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#             l_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
        
#             # 오른쪽 랜드마크
#             r_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
#             r_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
#             r_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            
#             # 왼쪽 각도
#             l_angle_knee = calculate_angle(l_hip, l_knee, l_ankle)
            
#             # 오른쪽 각도
#             r_angle_knee = calculate_angle(r_hip, r_knee, r_ankle)
            
            
            
#             # 각도를 눈에 보이게 표시
            
#             cv2.putText(image, "LEFT_KNEE:" + str(l_angle_knee), 
#                             tuple(np.multiply(l_knee, [300, 300]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
#             cv2.putText(image, "RIGHT_KNEE:" +  str(r_angle_knee), 
#                             tuple(np.multiply(r_knee, [300, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
    
            
            ##############################################################################################################
            
            
            #목 각도(엉덩이-무릎-발목)
#             왼쪽 랜드마크
#             l_eye = [landmarks[mp_pose.PoseLandmark.LEFT_EYE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_EYE.value].y]
#             nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]
#             l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
        
#             # 오른쪽 랜드마크
#             r_eye = [landmarks[mp_pose.PoseLandmark.RIGHT_EYE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_EYE.value].y]
#             nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]
#             r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
        
#             # 왼쪽 각도
#             l_angle_neck = calculate_angle(l_eye, nose, l_shoulder)
            
#             # 오른쪽 각도
#             r_angle_neck = calculate_angle(r_eye, nose, r_shoulder)
            
            
            
#             # 각도를 눈에 보이게 표시
            
#             cv2.putText(image, "LEFT :" +str(l_angle_neck), 
#                             tuple(np.multiply(l_eye, [400, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
#             cv2.putText(image, "RIGHT :" +str(r_angle_neck), 
#                             tuple(np.multiply(r_eye, [100, 200]).astype(int)), 
# #                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
            
            
            ##############################################################################################################
            
            '''
            # 왼쪽 자세 및 오른쪽 자세 판별 (왼쪽만 완성)
            l_eye = landmarks[mp_pose.PoseLandmark.LEFT_EYE.value].x
            l_ankle = landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x
            
            if l_eye > l_ankle:
                cv2.putText(image, "True", 
                            tuple(np.multiply(l_eye, [400, 400]).astype(int)), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 0), 2, cv2.LINE_AA)
                
                
            '''

  
            ##############################################################################################################
            
            ############################
            #  골반 기준 무릎 간격 비교#
            ############################
            
            ############################
            #  골반 기준 발목 간격 비교#
            ############################
            
            ### 선택 필요 ###
            
            #골반 사이 거리 (골반 왼쪽 - 오른쪽)
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#             r_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
           
#             hip_width = calculate_width(l_hip,r_hip)
            
#             # 각도를 눈에 보이게 표시
#             cv2.putText(image, "hip :" +str(hip_width), 
#                             tuple(np.multiply(l_hip, [200, 200]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 100, 100), 2, cv2.LINE_AA)
            
            
#             #무릎 사이 거리 (골반 왼쪽 - 오른쪽)
            
#             l_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#             r_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
           
#             KNEE_WIDTH = calculate_width(l_knee,r_knee)
            
#             # 각도를 눈에 보이게 표시
#             cv2.putText(image, "knee :" +str(KNEE_WIDTH), 
#                             tuple(np.multiply(l_knee, [200, 200]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 129, 255), 2, cv2.LINE_AA)
            
            
            
#             # 다리벌림방지 (27, 28)
#             #발목 사이 거리 (발목 왼쪽 - 오른쪽)
            
#             l_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
#             r_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
           
#             ankle_width = calculate_width(l_ankle,r_ankle)
                            
#             # 각도를 눈에 보이게 표시
            
#             cv2.putText(image, "ankle :" +str(ankle_width), 
#                             tuple(np.multiply([l_ankle[0],l_ankle[1]], [400, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (100, 100, 0), 2, cv2.LINE_AA)
            
            
            
            ##############################################################################################################
            
#             ############################
#             #  어깨 기준 손 간격 비교 #
#             ###########################
            
# #           # 기준이 되는 어깨 구하기
#             l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
           
#             shoulder_width = calculate_width(l_shoulder,r_shoulder)
                            
#             # 각도를 눈에 보이게 표시
            
#             cv2.putText(image, "shoulder :" +str(shoulder_width), 
#                             tuple(np.multiply(l_shoulder, [400, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (100, 100, 0), 2, cv2.LINE_AA)
            
#             # 손 사이 간격
#             l_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
#             r_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
           
#             wrist_width = calculate_width(l_wrist,r_wrist)
            
#             # 각도를 눈에 보이게 표시
#             cv2.putText(image, "wirst : "+str(wrist_width), 
#                             tuple(np.multiply(l_wrist, [300, 300]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 255), 2, cv2.LINE_AA)
            
            
            
         
            ##############################################################################################################
            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]
            l_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            cv2.putText(image, str(nose[1]), 
                            tuple(np.multiply(nose, [300, 300]).astype(int)), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 255), 2, cv2.LINE_AA)
            
            cv2.putText(image, str(l_wrist[1]), 
                            tuple(np.multiply(nose, [300, 500]).astype(int)), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)
            
            
            

        except:
            pass
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 56
#      53 ret, frame = cap.read()
#      55 # Recolor image to RGB
# ---> 56 image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      57 image.flags.writeable = False
#      59 # Make detection
#
# error: OpenCV(4.7.0) /Users/opencv-cn/GHA-OCV-3/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
nose[1]
# Out:
# 0.38548609614372253

# %% [markdown]
# # 스쿼트

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# 각도구하기
def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    
    return angle 


# 엉덩이 각도구하기
def rev_calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    angle = 360 - angle
    
    return angle 


# 거리구하기
def calculate_width(a,b):
    a = np.array(a) # First
    b = np.array(b) # End   
    
    width = ((a[0]-b[0])**2+(a[1]-b[1])**2)**0.5
    
    return width 



# './1.mp4'
cap = cv2.VideoCapture('./data/sq5.mp4')
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while True:
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            ##############################################################################################################
    # 좌우 기울어짐 확인
        #엉덩이(어깨-엉덩이-무릎)
            # 왼쪽 랜드마크
#             l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#             l_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#             # 오른쪽 랜드마크
#             r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
#             r_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
#             r_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            
#             # 왼쪽 각도
#             l_angle_hip = calculate_angle(l_shoulder, l_hip, l_knee)
            
#             # 오른쪽 각도
#             r_angle_hip = calculate_angle(r_shoulder, r_hip, r_knee)
            
            
            
#             #각도를 눈에 보이게 표시
            
#             cv2.putText(image, "l_hip:" + str(l_angle_hip), 
#                             tuple(np.multiply(l_hip, [100, 100]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (225, 0, 0), 2, cv2.LINE_AA)
            
#             cv2.putText(image, "r_hip:" +  str(r_angle_hip), 
#                             tuple(np.multiply(r_hip, [100, 200]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2, cv2.LINE_AA)
            
            
            ##############################################################################################################
    # 다운 정도 확인용            
        #무릎(엉덩이-무릎-발목) 
            # 왼쪽 랜드마크
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#             l_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#             l_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
        
#             # 오른쪽 랜드마크
#             r_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
#             r_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
#             r_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            
#             # 왼쪽 각도
#             l_angle_knee = calculate_angle(l_hip, l_knee, l_ankle)
            
#             # 오른쪽 각도
#             r_angle_knee = calculate_angle(r_hip, r_knee, r_ankle)
            
            
            
#             # 각도를 눈에 보이게 표시
            
#             cv2.putText(image, "LEFT_KNEE:" + str(l_angle_knee), 
#                             tuple(np.multiply(l_knee, [300, 300]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)
#             cv2.putText(image, "RIGHT_KNEE:" +  str(r_angle_knee), 
#                             tuple(np.multiply(r_knee, [300, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

          ##############################################################################################################  
    # 무릎 모아짐 확인
                
            #무릎 사이 거리 (골반 왼쪽 - 오른쪽)
#             l_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#             r_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
           
#             KNEE_WIDTH = calculate_width(l_knee,r_knee)
            
#             # 각도를 눈에 보이게 표시
#             cv2.putText(image, "knee :" +str(KNEE_WIDTH), 
#                             tuple(np.multiply(l_knee, [200, 200]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 129, 255), 2, cv2.LINE_AA)
            
            
#             #발목 사이 거리 (발목 왼쪽 - 오른쪽)
#             l_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
#             r_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
           
#             ankle_width = calculate_width(l_ankle,r_ankle)
                            
#             # 각도를 눈에 보이게 표시
            
#             cv2.putText(image, "ankle :" +str(ankle_width), 
#                             tuple(np.multiply([l_ankle[0],l_ankle[1]], [400, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (100, 100, 0), 2, cv2.LINE_AA)


            ##########################################################
    # 골반 y 좌표 
#             l_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#             cv2.putText(image, str(l_hip[1]), 
#                             tuple(np.multiply(l_hip, [400, 400]).astype(int)), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (100, 100, 0), 2, cv2.LINE_AA)
            
            ###########################################################
    # 발목 y좌표
            l_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            cv2.putText(image, str(l_ankle[1]), 
                            tuple(np.multiply(l_ankle, [400, 400]).astype(int)), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (100, 100, 0), 2, cv2.LINE_AA)
            
        except:
            pass
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# objc[15739]: Class CaptureDelegate is implemented in both /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/cv2/cv2.abi3.so (0x1545e2840) and /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/mediapipe/.dylibs/libopencv_videoio.3.4.16.dylib (0x155920860). One of the two will be used. Which one is undefined.
# objc[15739]: Class CVWindow is implemented in both /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/cv2/cv2.abi3.so (0x1545e2890) and /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x1553d8a68). One of the two will be used. Which one is undefined.
# objc[15739]: Class CVView is implemented in both /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/cv2/cv2.abi3.so (0x1545e28b8) and /opt/homebrew/anaconda3/envs/pipe/lib/python3.9/site-packages/mediapipe/.dylibs/libopencv_highgui.3.4.16.dylib (0x1553d8a90). One of the two will be used. Which one is undefined.
# ...

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >
